# %%
import gensim
import MeCab
import os
import glob
import pickle

# %%
root_dir = './jawiki_data/'  # 用意したデータのあるdirectory
infile_base = root_dir + 'jawiki-latest-pages-articles-'
N_ARTICLES = 551  # 記事数
MARK_ARTICLE = '=' * 20  # 記事ごとの分割マーク
sample_ratio = 0.3  # 時間節約のため全記事の30%のみ使用


SUFFIX_SPLIT = '_split_v2.txt'
SUFFIX_TOPIC = '_topicid_v2.txt'

# %%
def ja_tokenize(text):
    mecab = MeCab.Tagger("-Ochasen -d /opt/local/lib/mecab/dic/mecab-ipadic-neologd")
    mecab.parse('')
    lines = text.split('\n')
    results = []
    for s in lines:
        node = mecab.parseToNode(s)
        while node:
            features = node.feature.split(',')
            if features[0] != 'BOS/EOS':
                w = features[-3]  # word_base
                p = features[0]  # part of speech
                if p in ['名詞', '形容詞', '動詞']:
                    results.append(w)
            node = node.next
        results.append('\n')
    return results

def to_article_words(nums):
    fname_topicid =\
        infile_base + '%03d-%03d' % (nums[0], nums[-1]) + SUFFIX_TOPIC
    g = open(fname_topicid, 'w')
    for i in nums:
        path = infile_base + '%03d' % i + '.txt'
        print(path)
        file_split = path.replace('.txt', SUFFIX_SPLIT)

        text = open(path, 'r').read()
        text = text.lower()
        for word in ['file:', 'ファイル:', 'image:', '画像:']:
            text = text.replace('[[' + word, word)
        text = text.replace(']]', '').replace(':', ' ')
        for j, s in enumerate(text.split('\n\n[[')):
            words = ja_tokenize(s)
            if j == 0:
                wt = ' '.join(words)
            else:
                wt += MARK_ARTICLE + ' '.join(words)
            g.write('%d-%d: %s\n' % (i, j+1, s.split('\n')[0].replace('[', '').strip()))
        open(file_split, 'w').write(wt)
    g.close()

# %%
# 記事情報を単語情報に加工
nums = range(1, N_ARTICLES + 1)
to_article_words(nums)

# %%
# 記事ごとの単語情報を取得
import random
random.seed(0)

splitfiles = sorted(glob.glob(root_dir + '*' + SUFFIX_SPLIT))
#print(len(splitfiles), splitfiles)

docs = []
j = 0
g = open(infile_base + 'resample_docid_v2.txt', 'w')
for i, file_split in enumerate(splitfiles):
    print(file_split)
    texts0 = open(file_split, 'r').read().split(MARK_ARTICLE)
    n = len(texts0)
    indices = sorted(random.sample(range(n), int(sample_ratio * n)))
    for idx in indices:
        text = texts0[idx]
        docs.append(text.split())
        g.write('%d: %d-%d\n' % (j, i+1, idx+1))
        j += 1
#     break
g.close()
# Out:
# ./jawiki_data/jawiki-latest-pages-articles-001_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-002_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-003_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-004_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-005_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-006_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-007_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-008_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-009_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-010_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-011_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-012_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-013_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-014_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-015_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-016_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-017_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-018_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-019_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-020_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-021_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-022_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-023_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-024_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-025_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-026_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-027_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-028_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-029_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-030_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-031_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-032_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-033_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-034_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-035_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-036_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-037_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-038_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-039_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-040_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-041_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-042_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-043_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles
split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-394_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-395_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-396_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-397_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-398_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-399_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-400_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-401_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-402_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-403_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-404_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-405_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-406_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-407_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-408_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-409_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-410_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-411_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-412_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-413_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-414_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-415_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-416_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-417_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-418_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-419_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-420_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-421_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-422_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-423_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-424_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-425_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-426_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-427_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-428_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-429_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-430_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-431_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-432_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-433_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-434_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-435_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-436_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-437_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-438_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-439_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-440_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-441_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-442_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-443_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-444_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-445_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-446_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-447_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-448_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-449_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-450_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-451_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-452_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-453_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-454_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-455_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-456_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-457_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-458_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-459_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-460_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-461_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-462_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-463_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-464_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-465_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-466_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-467_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-468_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-469_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-470_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-471_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-472_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-473_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-474_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-475_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-476_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-477_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-478_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-479_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-480_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-481_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-482_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-483_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-484_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-485_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-486_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-487_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-488_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-489_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-490_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-491_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-492_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-493_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-494_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-495_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-496_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-497_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-498_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-499_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-500_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-501_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-502_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-503_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-504_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-505_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-506_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-507_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-508_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-509_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-510_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-511_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-512_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-513_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-514_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-515_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-516_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-517_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-518_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-519_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-520_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-521_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-522_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-523_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-524_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-525_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-526_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-527_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-528_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-529_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-530_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-531_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-532_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-533_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-534_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-535_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-536_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-537_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-538_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-539_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-540_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-541_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-542_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-543_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-544_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-545_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-546_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-547_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-548_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-549_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-550_split_v2.txt
# ./jawiki_data/jawiki-latest-pages-articles-551_split_v2.txt

# %%
# 記事ごとの単語情報から辞書を作成
if not os.path.exists('./jawiki_model'):
    os.mkdir('./jawiki_model')
dictionary = gensim.corpora.Dictionary(docs)
dictionary.save_as_text('./jawiki_model/jawiki_wordid_resample_no-filtered_v2.txt')

# あまり重要でない単語を除去
dictionary.filter_extremes(no_below=20, no_above=0.3, keep_n=None)
dictionary.save_as_text('./jawiki_model/jawiki_wordid_resample_v2.txt')

# %%
# 記事ごとの単語ベースの情報（コーパス）を作成
corpus = [dictionary.doc2bow(doc) for doc in docs]
gensim.corpora.MmCorpus.serialize('./jawiki_model/jawiki_bow_resample_v2.mm', corpus)

# %%
# コーパスをTFIDF化
tfidf = gensim.models.TfidfModel(corpus)
corpus_tfidf = tfidf[corpus]

with open('./jawiki_model/jawiki_tfidf_resample_v2.dump', mode='wb') as f:
    pickle.dump(corpus_tfidf, f)

# %%
# 上記で作成したコーパスを使い、LDAモデルで最適化する。
NUM_TOPICS = 100  # トピック数は100個とした

dictionary = gensim.corpora.Dictionary.load_from_text('./jawiki_model/jawiki_wordid_resample_v2.txt')
with open('./jawiki_model/jawiki_tfidf_resample_v2.dump', mode='rb') as f:
     corpus_tfidf = pickle.load(f)

lda = gensim.models.ldamulticore.LdaMulticore(corpus=corpus_tfidf, id2word=dictionary,
                                               num_topics=NUM_TOPICS, workers=3, minimum_probability=0.001,
                                               passes=20, chunksize=10000)
lda.save('./jawiki_model/jawiki_lda_v2.model')
